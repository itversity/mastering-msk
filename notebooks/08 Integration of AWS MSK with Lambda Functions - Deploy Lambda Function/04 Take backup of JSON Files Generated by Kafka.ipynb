# %%
# !aws s3 ls s3://airetail/topics/retail_logs/ --recursive
# Out:
# 2022-08-09 01:38:07      29096 topics/retail_logs/partition=0/retail_logs+0+0000011520.bin
# 2022-08-09 01:38:07      29349 topics/retail_logs/partition=0/retail_logs+0+0000011640.bin
# 2022-08-09 01:38:07      29353 topics/retail_logs/partition=0/retail_logs+0+0000011760.bin
# 2022-08-09 01:38:07      29165 topics/retail_logs/partition=0/retail_logs+0+0000011880.bin
# 2022-08-09 01:38:07      29204 topics/retail_logs/partition=0/retail_logs+0+0000012000.bin
# 2022-08-09 01:38:07      29199 topics/retail_logs/partition=0/retail_logs+0+0000012120.bin
# 2022-08-09 01:38:07      29333 topics/retail_logs/partition=0/retail_logs+0+0000012240.bin
# 2022-08-09 01:38:07      29517 topics/retail_logs/partition=0/retail_logs+0+0000012360.bin
# 2022-08-09 01:38:07      29233 topics/retail_logs/partition=0/retail_logs+0+0000012480.bin
# 2022-08-09 01:38:07      29221 topics/retail_logs/partition=0/retail_logs+0+0000012600.bin
# ...

# %%
# !aws s3 mv s3://airetail/topics/retail_logs/ \
    s3://airetail/topics/retail_logs_backup/ --recursive
# Out:
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000011640.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000011640.bin
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000012360.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000012360.bin
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000012000.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000012000.bin
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000012240.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000012240.bin
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000012120.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000012120.bin
# move: s3://airetail/topics/retail_logs/partition=0/retail_logs+0+0000011520.bin to s3://airetail/topics/retail_logs_backup/partition=0/retail_logs+0+0000011520.bin
# ...

# %%
# !aws s3 ls s3://airetail/topics/retail_logs/ --recursive

# %%
# !aws s3 ls s3://airetail/topics/retail_logs_backup/ --recursive
# Out:
# 2022-08-10 00:40:47      29096 topics/retail_logs_backup/partition=0/retail_logs+0+0000011520.bin
# 2022-08-10 00:40:47      29349 topics/retail_logs_backup/partition=0/retail_logs+0+0000011640.bin
# 2022-08-10 00:40:47      29353 topics/retail_logs_backup/partition=0/retail_logs+0+0000011760.bin
# 2022-08-10 00:40:47      29165 topics/retail_logs_backup/partition=0/retail_logs+0+0000011880.bin
# 2022-08-10 00:40:47      29204 topics/retail_logs_backup/partition=0/retail_logs+0+0000012000.bin
# 2022-08-10 00:40:47      29199 topics/retail_logs_backup/partition=0/retail_logs+0+0000012120.bin
# 2022-08-10 00:40:47      29333 topics/retail_logs_backup/partition=0/retail_logs+0+0000012240.bin
# 2022-08-10 00:40:47      29517 topics/retail_logs_backup/partition=0/retail_logs+0+0000012360.bin
# 2022-08-10 00:40:47      29233 topics/retail_logs_backup/partition=0/retail_logs+0+0000012480.bin
# 2022-08-10 00:40:47      29221 topics/retail_logs_backup/partition=0/retail_logs+0+0000012600.bin
# ...
